# %%
bk_zip_codes = ['11201', '11206', '11207', '11208', '11209', '11202', '11203', '11204', '11205', '11210', '11211', '11212', '11213', '11218', '11219', '11220', '11221', '11222', '11223', '11224', '11225', '11214', '11215', '11216', '11217', '11226', '11228', '11229', '11230', '11235', '11236', '11237', '11238', '11245', '11247', '11249', '11256', '11231', '11232', '11233', '11234', '11239', '11241', '11242', '11243', '11251', '11252']
len(bk_zip_codes)
# Out:
# 47

# %%
import os
from dotenv import load_dotenv
load_dotenv()
import requests
census_api_key = os.environ.get("CENSUS_API_KEY")
import pandas as pd
import time

# %%
import time
import pandas as pd
import requests

# ZIP code batches
bk_zip_codes = ['11201', '11206', '11207', '11208', '11209', '11202', '11203', '11204', '11205',
                '11210', '11211', '11212', '11213', '11218', '11219', '11220', '11221', '11222',
                '11223', '11224', '11225', '11214', '11215', '11216', '11217', '11226', '11228',
                '11229', '11230', '11235', '11236', '11237', '11238', '11245', '11247', '11249',
                '11256', '11231', '11232', '11233', '11234', '11239', '11241', '11242', '11243',
                '11251', '11252']

batch_size = 38
zip_batches = [bk_zip_codes[i:i + batch_size] for i in range(0, len(bk_zip_codes), batch_size)]
years = [2022, 2023]

# Store data from both years
all_data = pd.DataFrame()

for year in years:
    print(f"\n📅 Processing year: {year}")
    for i, batch in enumerate(zip_batches, start=1):
        zcta_str = ",".join(batch)
        url = f"https://api.census.gov/data/{year}/acs/acs5/subject?get=NAME,group(S1901)&for=zip%20code%20tabulation%20area:{zcta_str}&key={census_api_key}"

        print(f"🌐 Requesting batch {i} for year {year} with {len(batch)} ZCTAs...")

        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            data = response.json()

            if len(data) <= 1:
                print(f"⚠️ No data returned for batch {i}, year {year}")
            else:
                df = pd.DataFrame(data[1:], columns=data[0])
                df["year"] = year  # add a year column for distinction
                all_data = pd.concat([all_data, df], ignore_index=True)
                print(f"✅ Added {len(df)} rows from batch {i}, year {year}")
        except requests.exceptions.RequestException as e:
            print(f"❌ Request failed for batch {i}, year {year}: {e}")

        time.sleep(2)  # respect API limits

# Optionally reset index
all_data.reset_index(drop=True, inplace=True)
# Out:
# 📅 Processing year: 2022
# 🌐 Requesting batch 1 for year 2022 with 38 ZCTAs...
# ✅ Added 34 rows from batch 1, year 2022
# 🌐 Requesting batch 2 for year 2022 with 9 ZCTAs...
# ✅ Added 4 rows from batch 2, year 2022
#
# 📅 Processing year: 2023
# 🌐 Requesting batch 1 for year 2023 with 38 ZCTAs...
# ✅ Added 34 rows from batch 1, year 2023
# 🌐 Requesting batch 2 for year 2023 with 9 ZCTAs...
# ✅ Added 4 rows from batch 2, year 2023

# %%
# Get variable definitions
vars_url = "https://api.census.gov/data/2023/acs/acs5/subject/variables.json"
vars_response = requests.get(vars_url, timeout=10).json()
variables = vars_response['variables']

# match labels for S1901 variables
s1901_labels = {
    var: info['label'] 
    for var, info in variables.items() 
    if var.startswith("S1901_C01_") and var.endswith("E")
}

s1901_labels = s1901_labels.items()
s1901_labels = pd.DataFrame(s1901_labels)
s1901_labels.rename(columns={0: 'code_label', 1: 'readable_label'}, inplace=True)
s1901_labels.columns

s1901_labels.to_csv("s1901_labels.csv", index=False)

# %%
col_names = list(s1901_labels['code_label'])
columns_to_select = col_names + ['GEO_ID', 'zip code tabulation area']
filtered_data = all_data[columns_to_select]
filtered_data = filtered_data.rename(columns={"zip code tabulation area": "ZIP"})

# %%
import pandas as pd

def rename_columns_with_labels(data_df, labels_df):
    """
    Rename columns in data_df using human-readable labels from labels_df
    
    Args:
        data_df: DataFrame with code labels as column names
        labels_df: DataFrame with code_label and readable_label columns
    
    Returns:
        DataFrame with renamed columns
    """
    # Check if the expected columns exist in labels_df
    if 'code_label' not in labels_df.columns or 'readable_label' not in labels_df.columns:
        # Print the actual column names for debugging
        print(f"Available columns in labels dataframe: {labels_df.columns.tolist()}")
        raise ValueError("Labels dataframe must contain 'code_label' and 'readable_label' columns")
    
    # Clean the readable labels by replacing '!!' with a single space
    cleaned_labels = labels_df['readable_label'].str.replace('!!', ' ')
    
    # Create a dictionary mapping code labels to cleaned readable labels
    label_dict = dict(zip(labels_df['code_label'], cleaned_labels))
    
    # Create a copy of the original dataframe
    renamed_df = data_df.copy()
    
    # Rename columns that have corresponding readable labels
    columns_to_rename = {col: label_dict.get(col, col) for col in data_df.columns if col in label_dict}
    renamed_df = renamed_df.rename(columns=columns_to_rename)
    
    return renamed_df

renamed_df = rename_columns_with_labels(filtered_data, s1901_labels)

# Display the result
renamed_df.head()
# Out:
#   Estimate Households PERCENT ALLOCATED Nonfamily income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#   Estimate Households PERCENT ALLOCATED Family income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#   Estimate Households PERCENT ALLOCATED Household income in the past 12 months  \
# 0                                               31.5
# 1                                               59.5
# 2                                               50.4
# 3                                               43.3
# 4                                               45.6
#
#   Estimate Households Mean income (dollars)  \
# 0                                    232020
# 1                                     89068
# 2                                     83981
# 3                                    132369
# 4                                     81598
#
#   Estimate Households Median income (dollars)  \
# 0                                      163310
# 1                                       68006
# 2                                       64172
# 3                                       74839
# 4                                       51507
#
#   Estimate Households Total $200,000 or more  \
# 0                                       40.7
# 1                                        7.9
# 2                                        6.1
# 3                                       19.9
# 4                                        8.9
#
#   Estimate Households Total $150,000 to $199,999  \
# 0                                           12.4
# 1                                            8.3
# 2                                            8.8
# 3                                            8.6
# 4                                            6.7
#
#   Estimate Households Total $100,000 to $149,999  \
# 0                                           13.8
# 1                                           16.2
# 2                                           14.4
# 3                                           14.5
# 4                                           12.4
#
#   Estimate Households Total $75,000 to $99,999  \
# 0                                          5.8
# 1                                         12.8
# 2                                         14.1
# 3                                          6.9
# 4                                         10.8
#
#   Estimate Households Total $50,000 to $74,999  \
# 0                                          7.0
# 1                                         16.8
# 2                                         18.3
# 3                                         13.4
# 4                                         12.2
#
#   Estimate Households Total $35,000 to $49,999  \
# 0                                          4.7
# 1                                         11.6
# 2                                         10.6
# 3                                          9.7
# 4                                          9.3
#
#   Estimate Households Total $25,000 to $34,999  \
# 0                                          3.3
# 1                                          8.1
# 2                                          8.8
# 3                                          6.4
# 4                                          9.3
#
#   Estimate Households Total $15,000 to $24,999  \
# 0                                          3.8
# 1                                          6.1
# 2                                          9.1
# 3                                          7.0
# 4                                         12.3
#
#   Estimate Households Total $10,000 to $14,999  \
# 0                                          2.7
# 1                                          5.1
# 2                                          5.2
# 3                                          6.2
# 4                                          7.7
#
#   Estimate Households Total Less than $10,000 Estimate Households Total  \
# 0                                         5.7                     32227
# 1                                         7.1                     29411
# 2                                         4.6                     25118
# 3                                         7.4                     16861
# 4                                        10.3                     32698
#
#            GEO_ID    ZIP
# 0  860Z200US11201  11201
# 1  860Z200US11203  11203
# 2  860Z200US11204  11204
# 3  860Z200US11205  11205
# 4  860Z200US11206  11206

# %%
# BK DATA FOR 2023 INCOME BREAKDOWN BY ZIPCODE
bk_income_data_by_zip = renamed_df

bk_income_data_by_zip.to_csv("bk_income_data_by_zip.csv", index=False)

# %%
bk_income_data_by_zip.head()
# Out:
#   Estimate Households PERCENT ALLOCATED Nonfamily income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#   Estimate Households PERCENT ALLOCATED Family income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#   Estimate Households PERCENT ALLOCATED Household income in the past 12 months  \
# 0                                               31.5
# 1                                               59.5
# 2                                               50.4
# 3                                               43.3
# 4                                               45.6
#
#   Estimate Households Mean income (dollars)  \
# 0                                    232020
# 1                                     89068
# 2                                     83981
# 3                                    132369
# 4                                     81598
#
#   Estimate Households Median income (dollars)  \
# 0                                      163310
# 1                                       68006
# 2                                       64172
# 3                                       74839
# 4                                       51507
#
#   Estimate Households Total $200,000 or more  \
# 0                                       40.7
# 1                                        7.9
# 2                                        6.1
# 3                                       19.9
# 4                                        8.9
#
#   Estimate Households Total $150,000 to $199,999  \
# 0                                           12.4
# 1                                            8.3
# 2                                            8.8
# 3                                            8.6
# 4                                            6.7
#
#   Estimate Households Total $100,000 to $149,999  \
# 0                                           13.8
# 1                                           16.2
# 2                                           14.4
# 3                                           14.5
# 4                                           12.4
#
#   Estimate Households Total $75,000 to $99,999  \
# 0                                          5.8
# 1                                         12.8
# 2                                         14.1
# 3                                          6.9
# 4                                         10.8
#
#   Estimate Households Total $50,000 to $74,999  \
# 0                                          7.0
# 1                                         16.8
# 2                                         18.3
# 3                                         13.4
# 4                                         12.2
#
#   Estimate Households Total $35,000 to $49,999  \
# 0                                          4.7
# 1                                         11.6
# 2                                         10.6
# 3                                          9.7
# 4                                          9.3
#
#   Estimate Households Total $25,000 to $34,999  \
# 0                                          3.3
# 1                                          8.1
# 2                                          8.8
# 3                                          6.4
# 4                                          9.3
#
#   Estimate Households Total $15,000 to $24,999  \
# 0                                          3.8
# 1                                          6.1
# 2                                          9.1
# 3                                          7.0
# 4                                         12.3
#
#   Estimate Households Total $10,000 to $14,999  \
# 0                                          2.7
# 1                                          5.1
# 2                                          5.2
# 3                                          6.2
# 4                                          7.7
#
#   Estimate Households Total Less than $10,000 Estimate Households Total  \
# 0                                         5.7                     32227
# 1                                         7.1                     29411
# 2                                         4.6                     25118
# 3                                         7.4                     16861
# 4                                        10.3                     32698
#
#            GEO_ID    ZIP
# 0  860Z200US11201  11201
# 1  860Z200US11203  11203
# 2  860Z200US11204  11204
# 3  860Z200US11205  11205
# 4  860Z200US11206  11206

# %%
# Convert all relevant columns to numeric, coercing errors
bk_income_data_by_zip[bk_income_data_by_zip.columns] = bk_income_data_by_zip[bk_income_data_by_zip.columns].apply(pd.to_numeric, errors='coerce')
bk_income_data_by_zip.head()
# Out:
#    Estimate Households PERCENT ALLOCATED Nonfamily income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#    Estimate Households PERCENT ALLOCATED Family income in the past 12 months  \
# 0                                         -888888888
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
# 4                                         -888888888
#
#    Estimate Households PERCENT ALLOCATED Household income in the past 12 months  \
# 0                                               31.5
# 1                                               59.5
# 2                                               50.4
# 3                                               43.3
# 4                                               45.6
#
#    Estimate Households Mean income (dollars)  \
# 0                                     232020
# 1                                      89068
# 2                                      83981
# 3                                     132369
# 4                                      81598
#
#    Estimate Households Median income (dollars)  \
# 0                                       163310
# 1                                        68006
# 2                                        64172
# 3                                        74839
# 4                                        51507
#
#    Estimate Households Total $200,000 or more  \
# 0                                        40.7
# 1                                         7.9
# 2                                         6.1
# 3                                        19.9
# 4                                         8.9
#
#    Estimate Households Total $150,000 to $199,999  \
# 0                                            12.4
# 1                                             8.3
# 2                                             8.8
# 3                                             8.6
# 4                                             6.7
#
#    Estimate Households Total $100,000 to $149,999  \
# 0                                            13.8
# 1                                            16.2
# 2                                            14.4
# 3                                            14.5
# 4                                            12.4
#
#    Estimate Households Total $75,000 to $99,999  \
# 0                                           5.8
# 1                                          12.8
# 2                                          14.1
# 3                                           6.9
# 4                                          10.8
#
#    Estimate Households Total $50,000 to $74,999  \
# 0                                           7.0
# 1                                          16.8
# 2                                          18.3
# 3                                          13.4
# 4                                          12.2
#
#    Estimate Households Total $35,000 to $49,999  \
# 0                                           4.7
# 1                                          11.6
# 2                                          10.6
# 3                                           9.7
# 4                                           9.3
#
#    Estimate Households Total $25,000 to $34,999  \
# 0                                           3.3
# 1                                           8.1
# 2                                           8.8
# 3                                           6.4
# 4                                           9.3
#
#    Estimate Households Total $15,000 to $24,999  \
# 0                                           3.8
# 1                                           6.1
# 2                                           9.1
# 3                                           7.0
# 4                                          12.3
#
#    Estimate Households Total $10,000 to $14,999  \
# 0                                           2.7
# 1                                           5.1
# 2                                           5.2
# 3                                           6.2
# 4                                           7.7
#
#    Estimate Households Total Less than $10,000  Estimate Households Total  \
# 0                                          5.7                      32227
# 1                                          7.1                      29411
# 2                                          4.6                      25118
# 3                                          7.4                      16861
# 4                                         10.3                      32698
#
#    GEO_ID    ZIP
# 0     NaN  11201
# 1     NaN  11203
# 2     NaN  11204
# 3     NaN  11205
# 4     NaN  11206

# %%
# Step 1: Convert income bracket columns to numeric
bracket_cols = [
    'Estimate Households Total $200,000 or more',
    'Estimate Households Total $150,000 to $199,999',
    'Estimate Households Total $100,000 to $149,999',
    'Estimate Households Total $75,000 to $99,999',
    'Estimate Households Total $50,000 to $74,999',
    'Estimate Households Total $35,000 to $49,999',
    'Estimate Households Total $25,000 to $34,999',
    'Estimate Households Total $15,000 to $24,999',
    'Estimate Households Total $10,000 to $14,999',
    'Estimate Households Total Less than $10,000'
]

for col in bracket_cols:
    bk_income_data_by_zip[col] = pd.to_numeric(bk_income_data_by_zip[col], errors='coerce')

# Step 2: Create the consolidated income brackets based on new ranges

# Above $110k
bk_income_data_by_zip['Income Above $110k (%)'] = bk_income_data_by_zip[[
    'Estimate Households Total $200,000 or more',
    'Estimate Households Total $150,000 to $199,999'
]].sum(axis=1)

# $80k–$110k
bk_income_data_by_zip['Income $80k-$110k (%)'] = bk_income_data_by_zip[[
    'Estimate Households Total $100,000 to $149,999',
    'Estimate Households Total $75,000 to $99,999'
]].sum(axis=1)

# $40k–$80k
bk_income_data_by_zip['Income $40k-$80k (%)'] = bk_income_data_by_zip[[
    'Estimate Households Total $50,000 to $74,999',
    'Estimate Households Total $35,000 to $49,999'
]].sum(axis=1)

# Below $40k
bk_income_data_by_zip['Income Below $40k (%)'] = bk_income_data_by_zip[[
    'Estimate Households Total $25,000 to $34,999',
    'Estimate Households Total $15,000 to $24,999',
    'Estimate Households Total $10,000 to $14,999',
    'Estimate Households Total Less than $10,000'
]].sum(axis=1)

# Step 3: Calculate the absolute household counts using the percentages
bk_income_data_by_zip['Income Above $110k (count)'] = (bk_income_data_by_zip['Income Above $110k (%)'] / 100) * bk_income_data_by_zip['Estimate Households Total']
bk_income_data_by_zip['Income $80k-$110k (count)'] = (bk_income_data_by_zip['Income $80k-$110k (%)'] / 100) * bk_income_data_by_zip['Estimate Households Total']
bk_income_data_by_zip['Income $40k-$80k (count)'] = (bk_income_data_by_zip['Income $40k-$80k (%)'] / 100) * bk_income_data_by_zip['Estimate Households Total']
bk_income_data_by_zip['Income Below $40k (count)'] = (bk_income_data_by_zip['Income Below $40k (%)'] / 100) * bk_income_data_by_zip['Estimate Households Total']

# Round the counts to integers since they represent households
bk_income_data_by_zip['Income Above $110k (count)'] = bk_income_data_by_zip['Income Above $110k (count)'].round().astype(int)
bk_income_data_by_zip['Income $80k-$110k (count)'] = bk_income_data_by_zip['Income $80k-$110k (count)'].round().astype(int)
bk_income_data_by_zip['Income $40k-$80k (count)'] = bk_income_data_by_zip['Income $40k-$80k (count)'].round().astype(int)
bk_income_data_by_zip['Income Below $40k (count)'] = bk_income_data_by_zip['Income Below $40k (count)'].round().astype(int)

# Step 4: Create a simplified DataFrame with just the needed columns
simplified_df = bk_income_data_by_zip[[
    'ZIP',
    'Estimate Households Total',
    'Income Above $110k (%)', 'Income $80k-$110k (%)', 'Income $40k-$80k (%)', 'Income Below $40k (%)',
    'Income Above $110k (count)', 'Income $80k-$110k (count)', 'Income $40k-$80k (count)', 'Income Below $40k (count)'
]]

# Display the simplified DataFrame
print(simplified_df)

# Verify that the percentages still sum to approximately 100%
print("\nVerification - Sum of percentage columns:")
percentage_sum = simplified_df[['Income Above $110k (%)', 'Income $80k-$110k (%)', 'Income $40k-$80k (%)', 'Income Below $40k (%)']].sum(axis=1)
# print(percentage_sum)
# Out:
#       ZIP  Estimate Households Total  Income Above $110k (%)  \
# 0   11201                      32227                    53.1
# 1   11203                      29411                    16.2
# 2   11204                      25118                    14.9
# 3   11205                      16861                    28.5
# 4   11206                      32698                    15.6
# ..    ...                        ...                     ...
# 71  11249                      17621                    42.3
# 72  11232                       9336                    29.1
# 73  11233                      32784                    16.1
# 74  11234                      32178                    28.0
# 75  11239                       8320                     7.6
#
#     Income $80k-$110k (%)  Income $40k-$80k (%)  Income Below $40k (%)  \
# 0                    19.6                  11.7                   15.5
# 1                    29.0                  28.4                   26.4
# 2                    28.5                  28.9                   27.7
# 3                    21.4                  23.1                   27.0
# 4                    23.2                  21.5                   39.6
# ..                    ...                   ...                    ...
# 71                   22.1                  17.5                   18.1
# 72                   26.7                  21.3                   22.8
# 73                   27.5                  24.7                   31.6
# 74                   31.1                  20.1                   20.6
# 75                   16.1                  27.3                   49.1
#
#     Income Above $110k (count)  Income $80k-$110k (count)  \
# 0                        17113                       6316
# 1                         4765                       8529
# 2                         3743                       7159
# 3                         4805                       3608
# 4                         5101                       7586
# ..                         ...                        ...
# 71                        7454                       3894
# 72                        2717                       2493
# 73                        5278                       9016
# 74                        9010                      10007
# 75                         632                       1340
#
#     Income $40k-$80k (count)  Income Below $40k (count)
# 0                       3771                       4995
# 1                       8353                       7765
# 2                       7259                       6958
# 3                       3895                       4552
# 4                       7030                      12948
# ..                       ...                        ...
# 71                      3084                       3189
# 72                      1989                       2129
# 73                      8098                      10360
# 74                      6468                       6629
# 75                      2271                       4085
#
# [76 rows x 10 columns]

# %%
simplified_df.head()
# Out:
#      ZIP  Estimate Households Total  Income Above $110k (%)  \
# 0  11201                      32227                    53.1
# 1  11203                      29411                    16.2
# 2  11204                      25118                    14.9
# 3  11205                      16861                    28.5
# 4  11206                      32698                    15.6
#
#    Income $80k-$110k (%)  Income $40k-$80k (%)  Income Below $40k (%)  \
# 0                   19.6                  11.7                   15.5
# 1                   29.0                  28.4                   26.4
# 2                   28.5                  28.9                   27.7
# 3                   21.4                  23.1                   27.0
# 4                   23.2                  21.5                   39.6
#
#    Income Above $110k (count)  Income $80k-$110k (count)  \
# 0                       17113                       6316
# 1                        4765                       8529
# 2                        3743                       7159
# 3                        4805                       3608
# 4                        5101                       7586
#
#    Income $40k-$80k (count)  Income Below $40k (count)
# 0                      3771                       4995
# 1                      8353                       7765
# 2                      7259                       6958
# 3                      3895                       4552
# 4                      7030                      12948

# %%
# Step 5: Combine records with the same ZIP code using updated income brackets
combined_data = []

for zip_code, zip_group in simplified_df.groupby('ZIP'):
    if len(zip_group) == 1:
        # If there's only one record for this ZIP, use it as is
        combined_data.append(zip_group.iloc[0].to_dict())
    else:
        # For multiple records per ZIP, calculate weighted averages and sums
        total_households = zip_group['Estimate Households Total'].sum()
        
        # Calculate weighted average for percentages
        above_110k_pct = ((zip_group['Income Above $110k (%)'] * zip_group['Estimate Households Total']).sum() / 
                          total_households)
        income_80_110k_pct = ((zip_group['Income $80k-$110k (%)'] * zip_group['Estimate Households Total']).sum() / 
                              total_households)
        income_40_80k_pct = ((zip_group['Income $40k-$80k (%)'] * zip_group['Estimate Households Total']).sum() / 
                             total_households)
        below_40k_pct = ((zip_group['Income Below $40k (%)'] * zip_group['Estimate Households Total']).sum() / 
                         total_households)
        
        # Sum the counts
        above_110k_count = zip_group['Income Above $110k (count)'].sum()
        income_80_110k_count = zip_group['Income $80k-$110k (count)'].sum()
        income_40_80k_count = zip_group['Income $40k-$80k (count)'].sum()
        below_40k_count = zip_group['Income Below $40k (count)'].sum()
        
        # Create a combined record
        combined_record = {
            'ZIP': zip_code,
            'Estimate Households Total': total_households,
            'Income Above $110k (%)': above_110k_pct,
            'Income $80k-$110k (%)': income_80_110k_pct,
            'Income $40k-$80k (%)': income_40_80k_pct,
            'Income Below $40k (%)': below_40k_pct,
            'Income Above $110k (count)': above_110k_count,
            'Income $80k-$110k (count)': income_80_110k_count,
            'Income $40k-$80k (count)': income_40_80k_count,
            'Income Below $40k (count)': below_40k_count
        }
        combined_data.append(combined_record)

# Create the final combined DataFrame
final_df = pd.DataFrame(combined_data)

# Round percentages to 1 decimal place for display
for col in ['Income Above $110k (%)', 'Income $80k-$110k (%)', 'Income $40k-$80k (%)', 'Income Below $40k (%)']:
    final_df[col] = final_df[col].round(1)

# %%
final_df.head()
# Out:
#      ZIP  Estimate Households Total  Income Above $110k (%)  \
# 0  11201                      65368                    53.9
# 1  11203                      59560                    16.4
# 2  11204                      50424                    15.2
# 3  11205                      34133                    30.5
# 4  11206                      66394                    16.7
#
#    Income $80k-$110k (%)  Income $40k-$80k (%)  Income Below $40k (%)  \
# 0                   19.9                  11.4                   14.9
# 1                   29.1                  27.3                   27.2
# 2                   29.6                  28.3                   26.9
# 3                   22.2                  21.6                   25.7
# 4                   23.5                  22.2                   37.7
#
#    Income Above $110k (count)  Income $80k-$110k (count)  \
# 0                       35208                      12977
# 1                        9770                      17333
# 2                        7665                      14903
# 3                       10418                       7581
# 4                       11065                      15572
#
#    Income $40k-$80k (count)  Income Below $40k (count)
# 0                      7450                       9734
# 1                     16282                      16177
# 2                     14294                      13563
# 3                      7384                       8766
# 4                     14713                      25045

# %%
# %store final_df
# Out:
# Stored 'final_df' (DataFrame)
