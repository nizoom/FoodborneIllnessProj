# %%
import pandas as pd

# %%
inspection_data = pd.read_csv("restaurant_inspection.csv")

# %%
inspection_data = pd.DataFrame(inspection_data)

# %%
inspection_data.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA', 'Location Point1'],
#       dtype='object')

# %% [markdown]
# 1. filter inspection data by record date -> only keep records in 2023
# 2. For every restaurant in vioaltions df you're matching there violation codes and counting how many are critical and how many are general \
#     a. seems like theres a bunch of codes listed as "public health hazard" from the pdf too which are missing from violation_mapping
#     b. maybe like sum() of critical / general/ etc.
#
# 3. so the df should have cols: |geo data to mark on map| Total critical violations | total general| total public health vios |
# and the records are restaurants
